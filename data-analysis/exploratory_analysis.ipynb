# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_PATH = "docs/master_property_tax_enforcement_dataset.csv"

master_property = pd.read_csv(DATA_PATH, low_memory=False)

print(master_property.shape)
display(master_property.head())
# Out:
# (9763, 73)
#                      month       cycle  borough_lien  block_lien  lot_lien  \
# 0  2019-10-01T00:00:00.000  Final Sale             1          26      1260
# 1  2019-10-01T00:00:00.000  Final Sale             1          26      1273
# 2  2019-10-01T00:00:00.000  Final Sale             1          27      1040
# 3  2019-10-01T00:00:00.000  Final Sale             1          31      1068
# 4  2019-10-01T00:00:00.000  Final Sale             1          44      1265
#
#    tax_class_code building_class  community_board  council_district  \
# 0               2             R4            101.0               1.0
# 1               2             R4            101.0               1.0
# 2               2             R4            101.0               1.0
# 3               2             R4            101.0               1.0
# 4               2             R4            101.0               1.0
#
#   house_number  ... vacancy_rate  rent_burden_rate severe_rent_burden_rate  \
# 0           15  ...          NaN               NaN                     NaN
# 1           15  ...          NaN               NaN                     NaN
# 2           55  ...          NaN               NaN                     NaN
# 3           75  ...          NaN               NaN                     NaN
# 4           18  ...          NaN               NaN                     NaN
#
#    black_rate  hispanic_rate asian_rate  white_nonhispanic_rate  \
# 0         NaN            NaN        NaN                     NaN
# 1         NaN            NaN        NaN                     NaN
# 2         NaN            NaN        NaN                     NaN
# 3         NaN            NaN        NaN                     NaN
# 4         NaN            NaN        NaN                     NaN
#
#    age_65_plus_rate  bachelors_plus_rate  matched_acs
# 0               NaN                  NaN            0
# 1               NaN                  NaN            0
# 2               NaN                  NaN            0
# 3               NaN                  NaN            0
# 4               NaN                  NaN            0
#
# [5 rows x 73 columns]
